# %% [markdown]
# <a href="https://colab.research.google.com/github/UmarKhattab09/ML-Models-IN-DEPTH/blob/main/NaiveBaye's_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

#Step #1: Load your data
url = 'https://drive.google.com/file/d/17ftgPDTeaQOcBEI4eDRehk5qSZdFQKAv/view?usp=sharing'
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id
df = pd.read_csv(dwn_url)

# %%
df
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %% [markdown]
# ### Naive Baye Algorithm
# - This algorithm is for Classification Purposes.
# - It uses Probability formula to detect the output

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
X= df.drop('play',axis=1)
y=df['play']

# %%
### Converting the data into numerical using one hot encoding
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories=[['sunny', 'overcast', 'rainy']])
encoder2 = OrdinalEncoder(categories=[['hot', 'mild', 'cool']])
encoder3 = OrdinalEncoder(categories=[['high', 'normal']])
encoder4 = OrdinalEncoder(categories=[['True', 'False']])
encoder5 = OrdinalEncoder(categories=[['no', 'yes']])

df['Outlook_encoded'] = encoder.fit_transform(df[['outlook']])
df['temp_encoded'] = encoder2.fit_transform(df[['temp']])
df['humidity_encoded'] = encoder3.fit_transform(df[['humidity']])
df['play_encoded'] = encoder5.fit_transform(df[['play']])
df
# Out:
#      outlook  temp humidity  windy play  Outlook_encoded  temp_encoded  \
# 0      sunny   hot     high  False   no              0.0           0.0
# 1      sunny   hot     high   True   no              0.0           0.0
# 2   overcast   hot     high  False  yes              1.0           0.0
# 3      rainy  mild     high  False  yes              2.0           1.0
# 4      rainy  cool   normal  False  yes              2.0           2.0
# 5      rainy  cool   normal   True   no              2.0           2.0
# 6   overcast  cool   normal   True  yes              1.0           2.0
# 7      sunny  mild     high  False   no              0.0           1.0
# 8      sunny  cool   normal  False  yes              0.0           2.0
# 9      rainy  mild   normal  False  yes              2.0           1.0
# 10     sunny  mild   normal   True  yes              0.0           1.0
# 11  overcast  mild     high   True  yes              1.0           1.0
# ...

# %%
X = df.drop(['play','outlook','temp','humidity','play_encoded'],axis=1)
y = df['play_encoded']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)
X_train
# Out:
#     windy  Outlook_encoded  temp_encoded  humidity_encoded
# 8   False              0.0           2.0               1.0
# 2   False              1.0           0.0               0.0
# 1    True              0.0           0.0               0.0
# 13   True              2.0           1.0               0.0
# 4   False              2.0           2.0               1.0
# 7   False              0.0           1.0               0.0
# 10   True              0.0           1.0               1.0
# 3   False              2.0           1.0               0.0
# 6    True              1.0           2.0               1.0

# %%
training=model.fit(X_train,y_train)

# %%
len(df)
# Out:
# 14

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
confusion_matrix(y_test,y_pred)
# Out:
# array([[1, 1],
#        [1, 2]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50         2
#          1.0       0.67      0.67      0.67         3
#
#     accuracy                           0.60         5
#    macro avg       0.58      0.58      0.58         5
# weighted avg       0.60      0.60      0.60         5

# %%
import pandas as pd

# Input as a single row DataFrame
data = {
    'windy': [0],
    'Outlook_encoded': [0],
    'temp_encoded': [0],
    'humidity_encoded': [1],
}

input_df = pd.DataFrame(data)

# Predict
prediction = model.predict(input_df)
print("Prediction:", prediction)
# Out:
# Prediction: [1.]
